# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('tips')  #builtin dataset in seaborn no need to import

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
titanic =pd.read_csv("tested.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
flights =sns.load_dataset("flights")  #built in dataset in seaborn

# %%
iris = sns.load_dataset("iris")  #built in dataset in seaborn

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Bi-Variate Analysis
# ##### analysing two columns at once where column may be categorical or numerical or combination of both

# %% [markdown]
# ##### 1.Scatterplot (Numerical - Numerical)

# %%
sns.scatterplot(x='total_bill',y='tip',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Multi-variate analysis-
# #### used to analyze multiple columns altogether.
# <p style="color: blue;">
# Parameters used: hue, style</p>
# ###### so basically, hue is used to add a parameter for additional angle of analysis i.e. person is male or female and style is used to differentiate whether the given person is a male or female.

# %% [markdown]
# ### 1. Scatter plot (Numerical-Numerical)

# %%
sns.scatterplot(x='total_bill',y='tip',data=df,hue=df['sex'],style=df['smoker'],size=df['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Bi-Variate Analysis
# #### 2. Bar plot (Numerical- Categorical)

# %%
sns.barplot(x='Pclass',y='Fare',data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ### Multi-variate analysis
# ##### 2. BarPlot (Numerical- categorical)

# %%
sns.barplot(x='Pclass',y='Age',data=titanic,hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ### Bi-variate analysis
# #### 3. Box-plot( Numerical-categorical)
# ##### we can plot box plot of two parameters catregorical and numerical simulteanously.

# %%
sns.boxplot(x=titanic['Sex'],y=titanic['Age'],data=titanic)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ### Multi-variate analysis
# #### Box-plot (N-C)
# using hue parameter we can simply add another angle of analysis i.e anaother column

# %%
sns.boxplot(x=titanic['Sex'],y=titanic['Age'],data=titanic,hue=titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# here the orange box of male overlapped with the blue box which is why it is not visible

# %% [markdown]
# ### bi-variate Analysis
# #### 4. Distplot (Numerical -categorical)
# used to plot frequency distribution

# %%
sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False)
sns.distplot(titanic[titanic['Survived']==1]['Age'],hist=False)
# Out:
# /tmp/ipykernel_823/1261424998.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False)
# /tmp/ipykernel_823/1261424998.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ### Bi-variate analysis
# ##### 5. Heatmap (Categorical-Categorical)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
crosstab=pd.crosstab(titanic['Pclass'],titanic['Survived'])  #this tells us how many people survived or not in which
# P-class

# %%
crosstab
# Out:
# Survived    0   1
# Pclass
# 1          57  50
# 2          63  30
# 3         146  72

# %%
sns.heatmap(crosstab)
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic['Survived'] = pd.to_numeric(titanic['Survived'], errors='coerce')
titanic['Survived'] = titanic['Survived'].astype(float)
pass_survived=titanic.groupby('Pclass')['Survived'].mean() *100


#this shows the percentage of passengers who survived in titanic.

# %% [markdown]
# since, sometimes heatmap aren't able to communicate things well that's why we have to use aggregate fucntions like mean() to get to know how many exact percentage of things are related.

# %%
pass_survived
# Out:
# Pclass
# 1    46.728972
# 2    32.258065
# 3    33.027523
# Name: Survived, dtype: float64

# %%
pass_survived.plot(kind='bar') #this is a plot of percentage of passengers who survived in pclasses respectively
# Out:
# <Axes: xlabel='Pclass'>

# %% [markdown]
# ### 6. ClusterMap (Categorical-categorical)

# %%
crosstab=pd.crosstab(titanic['Parch'],titanic['Survived'])

# %%
crosstab
# Out:
# Survived  0.0  1.0
# Parch
# 0         225   99
# 1          24   28
# 2          13   20
# 3           1    2
# 4           0    2
# 5           1    0
# 6           1    0
# 9           1    1

# %%
sns.clustermap(crosstab)

# %% [markdown]
# ### clustermap is a great way of finding exact correlation between pairs-> each colored part is called
# ##Dendogram

# %% [markdown]
# ### 7. Pairplot-
# #### collection of scatterplot-> it automatically detects the numerical columns present in the dataset and plots a pairplot for them.

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')  # this will give u collection of scatter plots on the baiss of species
# since there are 3 different species of plants there are 3 differnet colors.

# %% [markdown]
# ### 8. Lineplot
# #### Joining all the dots of scatter plot makes lineplot -> used for trends analysis
#
# x-axis=> time based numbers

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.groupby('year')

# %%
sns.lineplot(x='year',y='passengers',data=flights)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>
