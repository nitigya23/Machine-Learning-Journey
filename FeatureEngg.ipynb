# %% [markdown]
# ### Feature Engineering-
# It is the process of using Domain Knowledge to extract features from raw data. these features can be used to imporve the performance of machine learning algos.![Screenshot 2026-07-14 150629.png](data:image/png;base64,...)
