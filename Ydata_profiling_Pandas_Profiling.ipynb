# %%
import pandas as pd

# %%
df=pd.read_csv("/content/train_and_test2.csv")

# %%
df
# Out:
#       Passengerid   Age      Fare  Sex  ...  Embarked  zero.17  zero.18  2urvived
# 0               1  22.0    7.2500    0  ...       2.0        0        0         0
# 1               2  38.0   71.2833    1  ...       0.0        0        0         1
# 2               3  26.0    7.9250    1  ...       2.0        0        0         1
# 3               4  35.0   53.1000    1  ...       2.0        0        0         1
# 4               5  35.0    8.0500    0  ...       2.0        0        0         0
# ...           ...   ...       ...  ...  ...       ...      ...      ...       ...
# 1304         1305  28.0    8.0500    0  ...       2.0        0        0         0
# 1305         1306  39.0  108.9000    1  ...       0.0        0        0         0
# 1306         1307  38.5    7.2500    0  ...       2.0        0        0         0
# 1307         1308  28.0    8.0500    0  ...       2.0        0        0         0
# ...

# %%
# !pip install pandas-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.6/262.6 kB 1.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.8/309.8 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 6.1 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=852273de450a79ede29f4544c4a82257c55ce94c4b6de498705d7ba0d6869044
#   Stored in directory: /root/.cache/pip/wheels/5f/d4/d7/4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.3
#     Uninstalling MarkupSafe-3.0.3:
#       Successfully uninstalled MarkupSafe-3.0.3
# ...

# %%
import sys

# Uninstall pandas-profiling first, as we will use ydata-profiling.
# !pip uninstall -y pandas-profiling

# Install ydata-profiling, which is the successor to pandas-profiling
# It should handle numba compatibility with Python 3.12 automatically.
# !pip install ydata-profiling

# Restarting the kernel is often necessary after major package installations/uninstalls.
# This ensures that newly installed packages are correctly loaded.
# If the error persists after running this cell, a manual kernel restart might be needed.
# print("Please restart the runtime (Runtime -> Restart runtime...) if the issue persists.")

# Import ProfileReport from ydata_profiling
# Out:
# WARNING: Skipping pandas-profiling as it is not installed.
# ...

# %%
from ydata_profiling import ProfileReport

# Generate the profile report
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
